# %%
# extracting data from https://data.cityofnewyork.us/Public-Safety/NYPD-Complaint-Data-Historic/qgea-i56i/about_data to sql dataset

#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("qgea-i56i", limit=2 000)

# %%
# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df.head()
# Out:
#   cmplnt_num             cmplnt_fr_dt cmplnt_fr_tm             cmplnt_to_dt  \
# 0  279759215  2023-12-31T00:00:00.000     14:30:00  2023-12-31T00:00:00.000
# 1  279741127  2023-12-31T00:00:00.000     02:43:00  2023-12-31T00:00:00.000
# 2  279779858  2023-12-31T00:00:00.000     11:34:00  2023-12-31T00:00:00.000
# 3  279761588  2023-12-31T00:00:00.000     11:53:00  2023-12-31T00:00:00.000
# 4  279757717  2023-12-31T00:00:00.000     14:50:00  2023-12-31T00:00:00.000
#
#   cmplnt_to_tm addr_pct_cd                   rpt_dt ky_cd  \
# 0     15:00:00          79  2023-12-31T00:00:00.000   106
# 1     03:06:00          47  2023-12-31T00:00:00.000   361
# 2     11:39:00          19  2023-12-31T00:00:00.000   352
# 3     11:57:00          13  2023-12-31T00:00:00.000   341
# 4     14:52:00           5  2023-12-31T00:00:00.000   578
#
#                        ofns_desc pd_cd  ... station_name vic_age_group  \
# 0                 FELONY ASSAULT   109  ...       (null)         25-44
# 1  OFF. AGNST PUB ORD SENSBLTY &   639  ...       (null)         18-24
# 2              CRIMINAL TRESPASS   205  ...       (null)       UNKNOWN
# 3                  PETIT LARCENY   333  ...       (null)       UNKNOWN
# 4                  HARRASSMENT 2   637  ...       (null)         18-24
#
#                    vic_race vic_sex :@computed_region_efsh_h5xi  \
# 0                     BLACK       M                       17618
# 1            WHITE HISPANIC       M                       11607
# 2                   UNKNOWN       D                       10090
# 3                   UNKNOWN       D                       12073
# 4  ASIAN / PACIFIC ISLANDER       F                       11723
#
#   :@computed_region_f5dn_yrer :@computed_region_yeji_bk3q  \
# 0                          69                           2
# 1                          29                           5
# 2                          23                           4
# 3                          11                           4
# 4                          70                           4
#
#   :@computed_region_92fq_4b7q :@computed_region_sbqj_enih transit_district
# 0                          49                          51              NaN
# 1                           2                          30              NaN
# 2                          51                          11              NaN
# 3                          50                           7              NaN
# 4                          32                           2              NaN
#
# [5 rows x 40 columns]
